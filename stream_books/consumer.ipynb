# %% [markdown]
# ## Consumer

# %%
from stream_pack.modelib.FraudModel import runModel
from stream_pack.dumplib.dump import load_data
from kafka import KafkaConsumer
from pymongo import MongoClient
import pandas as pd
import urllib.parse
import json
import os

if __name__ == "__main__":
    # Informasi koneksi ke PostgreSQL
    USERNAME = os.getenv("USER")
    PASSWORD = os.getenv("PASSWORD")
    HOST = os.getenv("HOST")
    DATABASE = os.getenv("DB_NAME")
    PASSWORD = urllib.parse.quote_plus(PASSWORD)

    # URL koneksi ke PostgreSQL
    db_url = f"postgresql+psycopg2://{USERNAME}:{PASSWORD}@{HOST}/{DATABASE}?sslmode=require"
    table_name = "old_information"

    new_data = {
        'step': 1,
        'type': 'PAYMENT',
        'amount': 9839.64,
        'oldbalanceOrg': 170136.0,
        'newbalanceOrig': 160296.36,
        'oldbalanceDest': 0.0,
        'newbalanceDest': 0.0
    }

    # Mengatur koneksi ke MongoDB
    mongo_client = MongoClient("mongodb://admin:password@localhost:27017/")
    db = mongo_client["ftde01"]
    collection = db["tes01-collection"]

    # Mengatur Kafka Consumer
    consumer = KafkaConsumer("ftde01-project4", bootstrap_servers='localhost')
    print("Starting the consumer")
    
    for msg in consumer:
        print(f"Records = {json.loads(msg.value)}")
        
        # Parsing pesan Kafka
        data = json.loads(msg.value)
        
        # Menjalankan prediksi menggunakan fungsi runModel
        prediction = runModel(new_data, os.getcwd())  # Ubah '.' dengan path packages jika diperlukan
        
        # Load data from DB
        df_old = load_data(table_name, db_url)
        df_old.columns

        # create DF producer
        producer = pd.DataFrame([data])
        data_merge = producer.merge(df_old,
                              how='inner',
                              on=['nameOrig', 
                                  'nameDest']
                                  )
        predict = data_merge.drop(['nameOrig', 'nameDest'], axis=1)
        predict = predict.to_dict('index')
        print(predict)

        # Menambahkan hasil prediksi ke data sebelum disimpan
        data_merge['prediction'] = prediction
        data_dict = data_merge.to_dict(orient='records')
        print(data_dict)

        # Menyimpan data ke MongoDB
        if isinstance(data, list):
            collection.insert_many(data)
        else:
            collection.insert_one(data)
        
        print("Data telah disimpan ke MongoDB")

        # Show data
        data_from_mongo = list(collection.find())
        dfm = pd.DataFrame(data_from_mongo)
        print(dfm)
# Out:
# Starting the consumer
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 9839.64, 'nameOrig': 'C1231006815', 'newbalanceOrig': 160296.36, 'nameDest': 'M1979787155', 'newbalanceDest': 0.0}
# {0: {'step': 1, 'type': 'PAYMENT', 'amount': 9839.64, 'newbalanceOrig': 160296.36, 'newbalanceDest': 0.0, 'oldbalanceOrg': 170136.0, 'oldbalanceDest': 0.0}}
# [{'step': 1, 'type': 'PAYMENT', 'amount': 9839.64, 'nameOrig': 'C1231006815', 'newbalanceOrig': 160296.36, 'nameDest': 'M1979787155', 'newbalanceDest': 0.0, 'oldbalanceOrg': 170136.0, 'oldbalanceDest': 0.0, 'prediction': 'White List'}]
# Data telah disimpan ke MongoDB
#                           _id  step      type     amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT    9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT    1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER     181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT     181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT   11668.14  C2048537720
# ..                        ...   ...       ...        ...          ...
# 214  6691dc80fdef16c603d35eaf     1   PAYMENT    2560.74  C1648232591
# 215  6691dc83fdef16c603d35eb0     1   PAYMENT   11633.76  C1716932897
# 216  6691dc86fdef16c603d35eb1     1   PAYMENT    4098.78  C1026483832
# 217  6691dc89fdef16c603d35eb2     1  CASH_OUT  229133.94   C905080434
# 218  6691dcf3fdef16c603d35eb4     1   PAYMENT    9839.64  C1231006815
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 214         2509.26   M972865270            0.00         NaN
# 215            0.00   M801569151            0.00         NaN
# 216       499165.22  M1635378213            0.00         NaN
# 217            0.00   C476402209        51513.44         NaN
# 218       160296.36  M1979787155            0.00         NaN
#
# [219 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 1864.28, 'nameOrig': 'C1666544295', 'newbalanceOrig': 19384.72, 'nameDest': 'M2044282225', 'newbalanceDest': 0.0}
# {0: {'step': 1, 'type': 'PAYMENT', 'amount': 1864.28, 'newbalanceOrig': 19384.72, 'newbalanceDest': 0.0, 'oldbalanceOrg': 21249.0, 'oldbalanceDest': 0.0}}
# [{'step': 1, 'type': 'PAYMENT', 'amount': 1864.28, 'nameOrig': 'C1666544295', 'newbalanceOrig': 19384.72, 'nameDest': 'M2044282225', 'newbalanceDest': 0.0, 'oldbalanceOrg': 21249.0, 'oldbalanceDest': 0.0, 'prediction': 'White List'}]
# Data telah disimpan ke MongoDB
#                           _id  step      type     amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT    9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT    1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER     181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT     181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT   11668.14  C2048537720
# ..                        ...   ...       ...        ...          ...
# 215  6691dc83fdef16c603d35eb0     1   PAYMENT   11633.76  C1716932897
# 216  6691dc86fdef16c603d35eb1     1   PAYMENT    4098.78  C1026483832
# 217  6691dc89fdef16c603d35eb2     1  CASH_OUT  229133.94   C905080434
# 218  6691dcf3fdef16c603d35eb4     1   PAYMENT    9839.64  C1231006815
# 219  6691dcf7fdef16c603d35eb5     1   PAYMENT    1864.28  C1666544295
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 215            0.00   M801569151            0.00         NaN
# 216       499165.22  M1635378213            0.00         NaN
# 217            0.00   C476402209        51513.44         NaN
# 218       160296.36  M1979787155            0.00         NaN
# 219        19384.72  M2044282225            0.00         NaN
#
# [220 rows x 9 columns]
# Records = {'step': 1, 'type': 'TRANSFER', 'amount': 181.0, 'nameOrig': 'C1305486145', 'newbalanceOrig': 0.0, 'nameDest': 'C553264065', 'newbalanceDest': 0.0}
# {0: {'step': 1, 'type': 'TRANSFER', 'amount': 181.0, 'newbalanceOrig': 0.0, 'newbalanceDest': 0.0, 'oldbalanceOrg': 181.0, 'oldbalanceDest': 0.0}}
# [{'step': 1, 'type': 'TRANSFER', 'amount': 181.0, 'nameOrig': 'C1305486145', 'newbalanceOrig': 0.0, 'nameDest': 'C553264065', 'newbalanceDest': 0.0, 'oldbalanceOrg': 181.0, 'oldbalanceDest': 0.0, 'prediction': 'White List'}]
# Data telah disimpan ke MongoDB
#                           _id  step      type     amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT    9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT    1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER     181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT     181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT   11668.14  C2048537720
# ..                        ...   ...       ...        ...          ...
# 216  6691dc86fdef16c603d35eb1     1   PAYMENT    4098.78  C1026483832
# 217  6691dc89fdef16c603d35eb2     1  CASH_OUT  229133.94   C905080434
# 218  6691dcf3fdef16c603d35eb4     1   PAYMENT    9839.64  C1231006815
# 219  6691dcf7fdef16c603d35eb5     1   PAYMENT    1864.28  C1666544295
# 220  6691dcfafdef16c603d35eb6     1  TRANSFER     181.00  C1305486145
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 216       499165.22  M1635378213            0.00         NaN
# 217            0.00   C476402209        51513.44         NaN
# 218       160296.36  M1979787155            0.00         NaN
# 219        19384.72  M2044282225            0.00         NaN
# 220            0.00   C553264065            0.00         NaN
#
# [221 rows x 9 columns]
# Records = {'step': 1, 'type': 'CASH_OUT', 'amount': 181.0, 'nameOrig': 'C840083671', 'newbalanceOrig': 0.0, 'nameDest': 'C38997010', 'newbalanceDest': 0.0}
# {0: {'step': 1, 'type': 'CASH_OUT', 'amount': 181.0, 'newbalanceOrig': 0.0, 'newbalanceDest': 0.0, 'oldbalanceOrg': 181.0, 'oldbalanceDest': 21182.0}}
# [{'step': 1, 'type': 'CASH_OUT', 'amount': 181.0, 'nameOrig': 'C840083671', 'newbalanceOrig': 0.0, 'nameDest': 'C38997010', 'newbalanceDest': 0.0, 'oldbalanceOrg': 181.0, 'oldbalanceDest': 21182.0, 'prediction': 'White List'}]
# Data telah disimpan ke MongoDB
#                           _id  step      type     amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT    9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT    1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER     181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT     181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT   11668.14  C2048537720
# ..                        ...   ...       ...        ...          ...
# 217  6691dc89fdef16c603d35eb2     1  CASH_OUT  229133.94   C905080434
# 218  6691dcf3fdef16c603d35eb4     1   PAYMENT    9839.64  C1231006815
# 219  6691dcf7fdef16c603d35eb5     1   PAYMENT    1864.28  C1666544295
# 220  6691dcfafdef16c603d35eb6     1  TRANSFER     181.00  C1305486145
# 221  6691dcfefdef16c603d35eb7     1  CASH_OUT     181.00   C840083671
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 217            0.00   C476402209        51513.44         NaN
# 218       160296.36  M1979787155            0.00         NaN
# 219        19384.72  M2044282225            0.00         NaN
# 220            0.00   C553264065            0.00         NaN
# 221            0.00    C38997010            0.00         NaN
#
# [222 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 11668.14, 'nameOrig': 'C2048537720', 'newbalanceOrig': 29885.86, 'nameDest': 'M1230701703', 'newbalanceDest': 0.0}
# {0: {'step': 1, 'type': 'PAYMENT', 'amount': 11668.14, 'newbalanceOrig': 29885.86, 'newbalanceDest': 0.0, 'oldbalanceOrg': 41554.0, 'oldbalanceDest': 0.0}}
# [{'step': 1, 'type': 'PAYMENT', 'amount': 11668.14, 'nameOrig': 'C2048537720', 'newbalanceOrig': 29885.86, 'nameDest': 'M1230701703', 'newbalanceDest': 0.0, 'oldbalanceOrg': 41554.0, 'oldbalanceDest': 0.0, 'prediction': 'White List'}]
# Data telah disimpan ke MongoDB
#                           _id  step      type    amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT   9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT   1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER    181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT    181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT  11668.14  C2048537720
# ..                        ...   ...       ...       ...          ...
# 218  6691dcf3fdef16c603d35eb4     1   PAYMENT   9839.64  C1231006815
# 219  6691dcf7fdef16c603d35eb5     1   PAYMENT   1864.28  C1666544295
# 220  6691dcfafdef16c603d35eb6     1  TRANSFER    181.00  C1305486145
# 221  6691dcfefdef16c603d35eb7     1  CASH_OUT    181.00   C840083671
# 222  6691dd01fdef16c603d35eb8     1   PAYMENT  11668.14  C2048537720
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155             0.0  White List
# 1          19384.72  M2044282225             0.0  White List
# 2              0.00   C553264065             0.0  White List
# 3              0.00    C38997010             0.0  White List
# 4          29885.86  M1230701703             0.0  White List
# ..              ...          ...             ...         ...
# 218       160296.36  M1979787155             0.0         NaN
# 219        19384.72  M2044282225             0.0         NaN
# 220            0.00   C553264065             0.0         NaN
# 221            0.00    C38997010             0.0         NaN
# 222        29885.86  M1230701703             0.0         NaN
#
# [223 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 7817.71, 'nameOrig': 'C90045638', 'newbalanceOrig': 46042.29, 'nameDest': 'M573487274', 'newbalanceDest': 0.0}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type    amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT   9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT   1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER    181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT    181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT  11668.14  C2048537720
# ..                        ...   ...       ...       ...          ...
# 219  6691dcf7fdef16c603d35eb5     1   PAYMENT   1864.28  C1666544295
# 220  6691dcfafdef16c603d35eb6     1  TRANSFER    181.00  C1305486145
# 221  6691dcfefdef16c603d35eb7     1  CASH_OUT    181.00   C840083671
# 222  6691dd01fdef16c603d35eb8     1   PAYMENT  11668.14  C2048537720
# 223  6691dd04fdef16c603d35eb9     1   PAYMENT   7817.71    C90045638
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155             0.0  White List
# 1          19384.72  M2044282225             0.0  White List
# 2              0.00   C553264065             0.0  White List
# 3              0.00    C38997010             0.0  White List
# 4          29885.86  M1230701703             0.0  White List
# ..              ...          ...             ...         ...
# 219        19384.72  M2044282225             0.0         NaN
# 220            0.00   C553264065             0.0         NaN
# 221            0.00    C38997010             0.0         NaN
# 222        29885.86  M1230701703             0.0         NaN
# 223        46042.29   M573487274             0.0         NaN
#
# [224 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 7107.77, 'nameOrig': 'C154988899', 'newbalanceOrig': 176087.23, 'nameDest': 'M408069119', 'newbalanceDest': 0.0}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type    amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT   9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT   1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER    181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT    181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT  11668.14  C2048537720
# ..                        ...   ...       ...       ...          ...
# 220  6691dcfafdef16c603d35eb6     1  TRANSFER    181.00  C1305486145
# 221  6691dcfefdef16c603d35eb7     1  CASH_OUT    181.00   C840083671
# 222  6691dd01fdef16c603d35eb8     1   PAYMENT  11668.14  C2048537720
# 223  6691dd04fdef16c603d35eb9     1   PAYMENT   7817.71    C90045638
# 224  6691dd08fdef16c603d35eba     1   PAYMENT   7107.77   C154988899
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155             0.0  White List
# 1          19384.72  M2044282225             0.0  White List
# 2              0.00   C553264065             0.0  White List
# 3              0.00    C38997010             0.0  White List
# 4          29885.86  M1230701703             0.0  White List
# ..              ...          ...             ...         ...
# 220            0.00   C553264065             0.0         NaN
# 221            0.00    C38997010             0.0         NaN
# 222        29885.86  M1230701703             0.0         NaN
# 223        46042.29   M573487274             0.0         NaN
# 224       176087.23   M408069119             0.0         NaN
#
# [225 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 7861.64, 'nameOrig': 'C1912850431', 'newbalanceOrig': 168225.59, 'nameDest': 'M633326333', 'newbalanceDest': 0.0}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type    amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT   9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT   1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER    181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT    181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT  11668.14  C2048537720
# ..                        ...   ...       ...       ...          ...
# 221  6691dcfefdef16c603d35eb7     1  CASH_OUT    181.00   C840083671
# 222  6691dd01fdef16c603d35eb8     1   PAYMENT  11668.14  C2048537720
# 223  6691dd04fdef16c603d35eb9     1   PAYMENT   7817.71    C90045638
# 224  6691dd08fdef16c603d35eba     1   PAYMENT   7107.77   C154988899
# 225  6691dd0cfdef16c603d35ebb     1   PAYMENT   7861.64  C1912850431
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155             0.0  White List
# 1          19384.72  M2044282225             0.0  White List
# 2              0.00   C553264065             0.0  White List
# 3              0.00    C38997010             0.0  White List
# 4          29885.86  M1230701703             0.0  White List
# ..              ...          ...             ...         ...
# 221            0.00    C38997010             0.0         NaN
# 222        29885.86  M1230701703             0.0         NaN
# 223        46042.29   M573487274             0.0         NaN
# 224       176087.23   M408069119             0.0         NaN
# 225       168225.59   M633326333             0.0         NaN
#
# [226 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 4024.36, 'nameOrig': 'C1265012928', 'newbalanceOrig': 0.0, 'nameDest': 'M1176932104', 'newbalanceDest': 0.0}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type    amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT   9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT   1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER    181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT    181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT  11668.14  C2048537720
# ..                        ...   ...       ...       ...          ...
# 222  6691dd01fdef16c603d35eb8     1   PAYMENT  11668.14  C2048537720
# 223  6691dd04fdef16c603d35eb9     1   PAYMENT   7817.71    C90045638
# 224  6691dd08fdef16c603d35eba     1   PAYMENT   7107.77   C154988899
# 225  6691dd0cfdef16c603d35ebb     1   PAYMENT   7861.64  C1912850431
# 226  6691dd10fdef16c603d35ebc     1   PAYMENT   4024.36  C1265012928
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155             0.0  White List
# 1          19384.72  M2044282225             0.0  White List
# 2              0.00   C553264065             0.0  White List
# 3              0.00    C38997010             0.0  White List
# 4          29885.86  M1230701703             0.0  White List
# ..              ...          ...             ...         ...
# 222        29885.86  M1230701703             0.0         NaN
# 223        46042.29   M573487274             0.0         NaN
# 224       176087.23   M408069119             0.0         NaN
# 225       168225.59   M633326333             0.0         NaN
# 226            0.00  M1176932104             0.0         NaN
#
# [227 rows x 9 columns]
# Records = {'step': 1, 'type': 'DEBIT', 'amount': 5337.77, 'nameOrig': 'C712410124', 'newbalanceOrig': 36382.23, 'nameDest': 'C195600860', 'newbalanceDest': 40348.79}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type    amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT   9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT   1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER    181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT    181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT  11668.14  C2048537720
# ..                        ...   ...       ...       ...          ...
# 223  6691dd04fdef16c603d35eb9     1   PAYMENT   7817.71    C90045638
# 224  6691dd08fdef16c603d35eba     1   PAYMENT   7107.77   C154988899
# 225  6691dd0cfdef16c603d35ebb     1   PAYMENT   7861.64  C1912850431
# 226  6691dd10fdef16c603d35ebc     1   PAYMENT   4024.36  C1265012928
# 227  6691dd13fdef16c603d35ebd     1     DEBIT   5337.77   C712410124
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 223        46042.29   M573487274            0.00         NaN
# 224       176087.23   M408069119            0.00         NaN
# 225       168225.59   M633326333            0.00         NaN
# 226            0.00  M1176932104            0.00         NaN
# 227        36382.23   C195600860        40348.79         NaN
#
# [228 rows x 9 columns]
# Records = {'step': 1, 'type': 'DEBIT', 'amount': 9644.94, 'nameOrig': 'C1900366749', 'newbalanceOrig': 0.0, 'nameDest': 'C997608398', 'newbalanceDest': 157982.12}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type    amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT   9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT   1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER    181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT    181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT  11668.14  C2048537720
# ..                        ...   ...       ...       ...          ...
# 224  6691dd08fdef16c603d35eba     1   PAYMENT   7107.77   C154988899
# 225  6691dd0cfdef16c603d35ebb     1   PAYMENT   7861.64  C1912850431
# 226  6691dd10fdef16c603d35ebc     1   PAYMENT   4024.36  C1265012928
# 227  6691dd13fdef16c603d35ebd     1     DEBIT   5337.77   C712410124
# 228  6691dd17fdef16c603d35ebe     1     DEBIT   9644.94  C1900366749
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 224       176087.23   M408069119            0.00         NaN
# 225       168225.59   M633326333            0.00         NaN
# 226            0.00  M1176932104            0.00         NaN
# 227        36382.23   C195600860        40348.79         NaN
# 228            0.00   C997608398       157982.12         NaN
#
# [229 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 3099.97, 'nameOrig': 'C249177573', 'newbalanceOrig': 17671.03, 'nameDest': 'M2096539129', 'newbalanceDest': 0.0}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type    amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT   9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT   1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER    181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT    181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT  11668.14  C2048537720
# ..                        ...   ...       ...       ...          ...
# 225  6691dd0cfdef16c603d35ebb     1   PAYMENT   7861.64  C1912850431
# 226  6691dd10fdef16c603d35ebc     1   PAYMENT   4024.36  C1265012928
# 227  6691dd13fdef16c603d35ebd     1     DEBIT   5337.77   C712410124
# 228  6691dd17fdef16c603d35ebe     1     DEBIT   9644.94  C1900366749
# 229  6691dd1afdef16c603d35ebf     1   PAYMENT   3099.97   C249177573
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 225       168225.59   M633326333            0.00         NaN
# 226            0.00  M1176932104            0.00         NaN
# 227        36382.23   C195600860        40348.79         NaN
# 228            0.00   C997608398       157982.12         NaN
# 229        17671.03  M2096539129            0.00         NaN
#
# [230 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 2560.74, 'nameOrig': 'C1648232591', 'newbalanceOrig': 2509.26, 'nameDest': 'M972865270', 'newbalanceDest': 0.0}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type    amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT   9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT   1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER    181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT    181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT  11668.14  C2048537720
# ..                        ...   ...       ...       ...          ...
# 226  6691dd10fdef16c603d35ebc     1   PAYMENT   4024.36  C1265012928
# 227  6691dd13fdef16c603d35ebd     1     DEBIT   5337.77   C712410124
# 228  6691dd17fdef16c603d35ebe     1     DEBIT   9644.94  C1900366749
# 229  6691dd1afdef16c603d35ebf     1   PAYMENT   3099.97   C249177573
# 230  6691dd1efdef16c603d35ec0     1   PAYMENT   2560.74  C1648232591
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 226            0.00  M1176932104            0.00         NaN
# 227        36382.23   C195600860        40348.79         NaN
# 228            0.00   C997608398       157982.12         NaN
# 229        17671.03  M2096539129            0.00         NaN
# 230         2509.26   M972865270            0.00         NaN
#
# [231 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 11633.76, 'nameOrig': 'C1716932897', 'newbalanceOrig': 0.0, 'nameDest': 'M801569151', 'newbalanceDest': 0.0}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type    amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT   9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT   1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER    181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT    181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT  11668.14  C2048537720
# ..                        ...   ...       ...       ...          ...
# 227  6691dd13fdef16c603d35ebd     1     DEBIT   5337.77   C712410124
# 228  6691dd17fdef16c603d35ebe     1     DEBIT   9644.94  C1900366749
# 229  6691dd1afdef16c603d35ebf     1   PAYMENT   3099.97   C249177573
# 230  6691dd1efdef16c603d35ec0     1   PAYMENT   2560.74  C1648232591
# 231  6691dd21fdef16c603d35ec1     1   PAYMENT  11633.76  C1716932897
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 227        36382.23   C195600860        40348.79         NaN
# 228            0.00   C997608398       157982.12         NaN
# 229        17671.03  M2096539129            0.00         NaN
# 230         2509.26   M972865270            0.00         NaN
# 231            0.00   M801569151            0.00         NaN
#
# [232 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 4098.78, 'nameOrig': 'C1026483832', 'newbalanceOrig': 499165.22, 'nameDest': 'M1635378213', 'newbalanceDest': 0.0}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type    amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT   9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT   1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER    181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT    181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT  11668.14  C2048537720
# ..                        ...   ...       ...       ...          ...
# 228  6691dd17fdef16c603d35ebe     1     DEBIT   9644.94  C1900366749
# 229  6691dd1afdef16c603d35ebf     1   PAYMENT   3099.97   C249177573
# 230  6691dd1efdef16c603d35ec0     1   PAYMENT   2560.74  C1648232591
# 231  6691dd21fdef16c603d35ec1     1   PAYMENT  11633.76  C1716932897
# 232  6691dd24fdef16c603d35ec2     1   PAYMENT   4098.78  C1026483832
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 228            0.00   C997608398       157982.12         NaN
# 229        17671.03  M2096539129            0.00         NaN
# 230         2509.26   M972865270            0.00         NaN
# 231            0.00   M801569151            0.00         NaN
# 232       499165.22  M1635378213            0.00         NaN
#
# [233 rows x 9 columns]
# Records = {'step': 1, 'type': 'CASH_OUT', 'amount': 229133.94, 'nameOrig': 'C905080434', 'newbalanceOrig': 0.0, 'nameDest': 'C476402209', 'newbalanceDest': 51513.44}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type     amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT    9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT    1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER     181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT     181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT   11668.14  C2048537720
# ..                        ...   ...       ...        ...          ...
# 229  6691dd1afdef16c603d35ebf     1   PAYMENT    3099.97   C249177573
# 230  6691dd1efdef16c603d35ec0     1   PAYMENT    2560.74  C1648232591
# 231  6691dd21fdef16c603d35ec1     1   PAYMENT   11633.76  C1716932897
# 232  6691dd24fdef16c603d35ec2     1   PAYMENT    4098.78  C1026483832
# 233  6691dd28fdef16c603d35ec3     1  CASH_OUT  229133.94   C905080434
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 229        17671.03  M2096539129            0.00         NaN
# 230         2509.26   M972865270            0.00         NaN
# 231            0.00   M801569151            0.00         NaN
# 232       499165.22  M1635378213            0.00         NaN
# 233            0.00   C476402209        51513.44         NaN
#
# [234 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 1563.82, 'nameOrig': 'C761750706', 'newbalanceOrig': 0.0, 'nameDest': 'M1731217984', 'newbalanceDest': 0.0}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type     amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT    9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT    1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER     181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT     181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT   11668.14  C2048537720
# ..                        ...   ...       ...        ...          ...
# 230  6691dd1efdef16c603d35ec0     1   PAYMENT    2560.74  C1648232591
# 231  6691dd21fdef16c603d35ec1     1   PAYMENT   11633.76  C1716932897
# 232  6691dd24fdef16c603d35ec2     1   PAYMENT    4098.78  C1026483832
# 233  6691dd28fdef16c603d35ec3     1  CASH_OUT  229133.94   C905080434
# 234  6691dd2bfdef16c603d35ec4     1   PAYMENT    1563.82   C761750706
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 230         2509.26   M972865270            0.00         NaN
# 231            0.00   M801569151            0.00         NaN
# 232       499165.22  M1635378213            0.00         NaN
# 233            0.00   C476402209        51513.44         NaN
# 234            0.00  M1731217984            0.00         NaN
#
# [235 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 1157.86, 'nameOrig': 'C1237762639', 'newbalanceOrig': 19998.14, 'nameDest': 'M1877062907', 'newbalanceDest': 0.0}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type     amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT    9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT    1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER     181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT     181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT   11668.14  C2048537720
# ..                        ...   ...       ...        ...          ...
# 231  6691dd21fdef16c603d35ec1     1   PAYMENT   11633.76  C1716932897
# 232  6691dd24fdef16c603d35ec2     1   PAYMENT    4098.78  C1026483832
# 233  6691dd28fdef16c603d35ec3     1  CASH_OUT  229133.94   C905080434
# 234  6691dd2bfdef16c603d35ec4     1   PAYMENT    1563.82   C761750706
# 235  6691dd2efdef16c603d35ec5     1   PAYMENT    1157.86  C1237762639
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 231            0.00   M801569151            0.00         NaN
# 232       499165.22  M1635378213            0.00         NaN
# 233            0.00   C476402209        51513.44         NaN
# 234            0.00  M1731217984            0.00         NaN
# 235        19998.14  M1877062907            0.00         NaN
#
# [236 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 671.64, 'nameOrig': 'C2033524545', 'newbalanceOrig': 14451.36, 'nameDest': 'M473053293', 'newbalanceDest': 0.0}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type     amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT    9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT    1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER     181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT     181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT   11668.14  C2048537720
# ..                        ...   ...       ...        ...          ...
# 232  6691dd24fdef16c603d35ec2     1   PAYMENT    4098.78  C1026483832
# 233  6691dd28fdef16c603d35ec3     1  CASH_OUT  229133.94   C905080434
# 234  6691dd2bfdef16c603d35ec4     1   PAYMENT    1563.82   C761750706
# 235  6691dd2efdef16c603d35ec5     1   PAYMENT    1157.86  C1237762639
# 236  6691dd32fdef16c603d35ec6     1   PAYMENT     671.64  C2033524545
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 232       499165.22  M1635378213            0.00         NaN
# 233            0.00   C476402209        51513.44         NaN
# 234            0.00  M1731217984            0.00         NaN
# 235        19998.14  M1877062907            0.00         NaN
# 236        14451.36   M473053293            0.00         NaN
#
# [237 rows x 9 columns]
# Records = {'step': 1, 'type': 'TRANSFER', 'amount': 215310.3, 'nameOrig': 'C1670993182', 'newbalanceOrig': 0.0, 'nameDest': 'C1100439041', 'newbalanceDest': 0.0}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type     amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT    9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT    1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER     181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT     181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT   11668.14  C2048537720
# ..                        ...   ...       ...        ...          ...
# 233  6691dd28fdef16c603d35ec3     1  CASH_OUT  229133.94   C905080434
# 234  6691dd2bfdef16c603d35ec4     1   PAYMENT    1563.82   C761750706
# 235  6691dd2efdef16c603d35ec5     1   PAYMENT    1157.86  C1237762639
# 236  6691dd32fdef16c603d35ec6     1   PAYMENT     671.64  C2033524545
# 237  6691dd35fdef16c603d35ec7     1  TRANSFER  215310.30  C1670993182
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155            0.00  White List
# 1          19384.72  M2044282225            0.00  White List
# 2              0.00   C553264065            0.00  White List
# 3              0.00    C38997010            0.00  White List
# 4          29885.86  M1230701703            0.00  White List
# ..              ...          ...             ...         ...
# 233            0.00   C476402209        51513.44         NaN
# 234            0.00  M1731217984            0.00         NaN
# 235        19998.14  M1877062907            0.00         NaN
# 236        14451.36   M473053293            0.00         NaN
# 237            0.00  C1100439041            0.00         NaN
#
# [238 rows x 9 columns]
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 1373.43, 'nameOrig': 'C20804602', 'newbalanceOrig': 12480.57, 'nameDest': 'M1344519051', 'newbalanceDest': 0.0}
# {}
# []
# Data telah disimpan ke MongoDB
#                           _id  step      type     amount     nameOrig  \
# 0    6691bd95bad1327df42486dd     1   PAYMENT    9839.64  C1231006815
# 1    6691bd95bad1327df42486de     1   PAYMENT    1864.28  C1666544295
# 2    6691bd95bad1327df42486df     1  TRANSFER     181.00  C1305486145
# 3    6691bd96bad1327df42486e0     1  CASH_OUT     181.00   C840083671
# 4    6691bd97bad1327df42486e1     1   PAYMENT   11668.14  C2048537720
# ..                        ...   ...       ...        ...          ...
# 234  6691dd2bfdef16c603d35ec4     1   PAYMENT    1563.82   C761750706
# 235  6691dd2efdef16c603d35ec5     1   PAYMENT    1157.86  C1237762639
# 236  6691dd32fdef16c603d35ec6     1   PAYMENT     671.64  C2033524545
# 237  6691dd35fdef16c603d35ec7     1  TRANSFER  215310.30  C1670993182
# 238  6691dd38fdef16c603d35ec8     1   PAYMENT    1373.43    C20804602
#
#      newbalanceOrig     nameDest  newbalanceDest  prediction
# 0         160296.36  M1979787155             0.0  White List
# 1          19384.72  M2044282225             0.0  White List
# 2              0.00   C553264065             0.0  White List
# 3              0.00    C38997010             0.0  White List
# 4          29885.86  M1230701703             0.0  White List
# ..              ...          ...             ...         ...
# 234            0.00  M1731217984             0.0         NaN
# 235        19998.14  M1877062907             0.0         NaN
# 236        14451.36   M473053293             0.0         NaN
# 237            0.00  C1100439041             0.0         NaN
# 238        12480.57  M1344519051             0.0         NaN
#
# [239 rows x 9 columns]
# Records = {'step': 1, 'type': 'DEBIT', 'amount': 9302.79, 'nameOrig': 'C1566511282', 'newbalanceOrig': 1996.21, 'nameDest': 'C1973538135', 'newbalanceDest': 16896.7}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 51
#      48 prediction = runModel(new_data, os.getcwd())  # Ubah '.' dengan path packages jika diperlukan
#      50 # Load data from DB
# ---> 51 df_old = load_data(table_name, db_url)
#      52 df_old.columns
#      54 # create DF producer
#
# File d:\stream-fraud-detection\stream_books\stream_pack\dumplib\dump.py:20, in load_data(table_name, db_url)
#      17 def load_data(table_name, db_url):
#      18     engine = create_engine(db_url)
# ---> 20     return pd.read_sql(f"SELECT * FROM {table_name}", engine).head(5)
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\pandas\io\sql.py:704, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     701     dtype_backend = "numpy"  # type: ignore[assignment]
#     702 assert dtype_backend is not lib.no_default
# --> 704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
#     706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#    (...)
#     714             dtype=dtype,
#     715         )
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\pandas\io\sql.py:906, in pandasSQL_builder(con, schema, need_transaction)
#     903     raise ImportError("Using URI string without sqlalchemy installed.")
#     905 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 906     return SQLDatabase(con, schema, need_transaction)
#     908 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     909 if adbc and isinstance(con, adbc.Connection):
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\pandas\io\sql.py:1636, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1634     self.exit_stack.callback(con.dispose)
#    1635 if isinstance(con, Engine):
# -> 1636     con = self.exit_stack.enter_context(con.connect())
#    1637 if need_transaction and not con.in_transaction():
#    1638     self.exit_stack.enter_context(con.begin())
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\engine\base.py:3276, in Engine.connect(self)
#    3253 def connect(self) -> Connection:
#    3254     """Return a new :class:`_engine.Connection` object.
#    3255
#    3256     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3273
#    3274     """
# -> 3276     return self._connection_cls(self)
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\engine\base.py:3300, in Engine.raw_connection(self)
#    3278 def raw_connection(self) -> PoolProxiedConnection:
#    3279     """Return a "raw" DBAPI connection from the connection pool.
#    3280
#    3281     The returned object is a proxied version of the DBAPI
#    (...)
#    3298
#    3299     """
# -> 3300     return self.pool.connect()
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\pool\base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\pool\base.py:914, in _ConnectionRecord.__connect(self)
#     906     pool.dispatch.first_connect.for_modify(
#     907         pool.dispatch
#     908     ).exec_once_unless_exception(self.dbapi_connection, self)
#     910 # init of the dialect now takes place within the connect
#     911 # event, so ensure a mutex is used on the first run
#     912 pool.dispatch.connect.for_modify(
#     913     pool.dispatch
# --> 914 )._exec_w_sync_on_first_run(self.dbapi_connection, self)
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\event\attr.py:483, in _CompoundListener._exec_w_sync_on_first_run(self, *args, **kw)
#     481 with self._exec_once_mutex:
#     482     try:
# --> 483         self(*args, **kw)
#     484     except:
#     485         raise
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\event\attr.py:497, in _CompoundListener.__call__(self, *args, **kw)
#     495     fn(*args, **kw)
#     496 for fn in self.listeners:
# --> 497     fn(*args, **kw)
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:1912, in only_once.<locals>.go(*arg, **kw)
#    1910 once_fn = once.pop()
#    1911 try:
# -> 1912     return once_fn(*arg, **kw)
#    1913 except:
#    1914     if retry_on_exception:
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\engine\create.py:749, in create_engine.<locals>.first_connect(dbapi_connection, connection_record)
#     746 c._execution_options = util.EMPTY_DICT
#     748 try:
# --> 749     dialect.initialize(c)
#     750 finally:
#     751     # note that "invalidated" and "closed" are mutually
#     752     # exclusive in 1.4 Connection.
#     753     if not c.invalidated and not c.closed:
#     754         # transaction is rolled back otherwise, tested by
#     755         # test/dialect/postgresql/test_dialect.py
#     756         # ::MiscBackendTest::test_initial_transaction_state
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:677, in PGDialect_psycopg2.initialize(self, connection)
#     676 def initialize(self, connection):
# --> 677     super().initialize(connection)
#     678     self._has_native_hstore = (
#     679         self.use_native_hstore
#     680         and self._hstore_oids(connection.connection.dbapi_connection)
#     681         is not None
#     682     )
#     684     self.supports_sane_multi_rowcount = (
#     685         self.executemany_mode is not EXECUTEMANY_VALUES_PLUS_BATCH
#     686     )
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\dialects\postgresql\base.py:3115, in PGDialect.initialize(self, connection)
#    3114 def initialize(self, connection):
# -> 3115     super().initialize(connection)
#    3117     # https://www.postgresql.org/docs/9.3/static/release-9-2.html#AEN116689
#    3118     self.supports_smallserial = self.server_version_info >= (9, 2)
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\engine\default.py:518, in DefaultDialect.initialize(self, connection)
#     516 def initialize(self, connection):
#     517     try:
# --> 518         self.server_version_info = self._get_server_version_info(
#     519             connection
#     520         )
#     521     except NotImplementedError:
#     522         self.server_version_info = None
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\dialects\postgresql\base.py:3383, in PGDialect._get_server_version_info(self, connection)
#    3382 def _get_server_version_info(self, connection):
# -> 3383     v = connection.exec_driver_sql("select pg_catalog.version()").scalar()
#    3384     m = re.match(
#    3385         r".*(?:PostgreSQL|EnterpriseDB) "
#    3386         r"(\d+)\.?(\d+)?(?:\.(\d+))?(?:\.\d+)?(?:devel|beta)?",
#    3387         v,
#    3388     )
#    3389     if not m:
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\engine\base.py:1779, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1774 execution_options = self._execution_options.merge_with(
#    1775     execution_options
#    1776 )
#    1778 dialect = self.dialect
# -> 1779 ret = self._execute_context(
#    1780     dialect,
#    1781     dialect.execution_ctx_cls._init_statement,
#    1782     statement,
#    1783     None,
#    1784     execution_options,
#    1785     statement,
#    1786     distilled_parameters,
#    1787 )
#    1789 return ret
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\engine\base.py:2356, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2354     else:
#    2355         assert exc_info[1] is not None
# -> 2356         raise exc_info[1].with_traceback(exc_info[2])
#    2357 finally:
#    2358     del self._reentrant_error
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File d:\stream-fraud-detection\venv\Lib\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\encodings\utf_8.py:15, in decode(input, errors)
#      11 ### Codec APIs
#      13 encode = codecs.utf_8_encode
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      18 class IncrementalEncoder(codecs.IncrementalEncoder):
#
# KeyboardInterrupt:
